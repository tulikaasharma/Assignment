# %%
import requests
from bs4 import BeautifulSoup

# %%
result=requests.get('https://www.ourbus.com/routes')

# %%
src = result.content

# %%
soup = BeautifulSoup(src,'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE html>
#
# <html lang="en-us">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <title>OurBus- The Smart Commuter</title>
# <link href="https://d1w2yiidc2zb17.cloudfront.net/web/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js" type="text/javascript"></script>
# <link href="/resources/bootstrap-3.3.7/css/bootstrap-theme.min.css" rel="stylesheet" type="text/css">
# <link href="/resources/bootstrap-3.3.7/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
# <link href="/resources/css/style.css?v=2.8" rel="stylesheet" type="text/css"/>
# <link href="/resources/css/search-drop-down.css" rel="stylesheet" type="text/css"/>
# ...

# %%
container = soup.find_all('div' , class_='section_hgt secnd_sec_pdd')

# %%
print(type(container))
# Out:
# <class 'bs4.element.ResultSet'>

# %%
container
# Out:
# []

# %%
urls=[]

# %%
for div_tag in container:
# Out:
#   File "<ipython-input-61-fe77eeb4f728>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing
